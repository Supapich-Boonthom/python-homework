# %% [markdown]
# # แบบฝึกหัด: Dictionary และ Tuple ใน Python
#
# จำนวน 10 ข้อ - สำหรับนักศึกษาที่ต้องการฝึกการใช้งาน Dictionary และ Tuple

# %%
"""
    นางสาวศุภาพิชญ์ บุญถม รหัสนักศึกษา 6812732136
"""

# %% [markdown]
# ## ข้อ 1: สร้าง Dictionary และเข้าถึงค่า
#
# สร้าง dictionary ชื่อ `student` ที่มีข้อมูลดังนี้:
# - "name": "สมชาย"
# - "age": 20
# - "grade": "A"
# - "major": "วิทยาศาสตร์คอมพิวเตอร์"
#
# จากนั้นให้พิมพ์ชื่อและเกรดของนักเรียน

# %%
# เขียนคำตอบของคุณที่นี่
student = {"name":"สมชาย", "age":20, "grade":"A", "major":"วิทยาการคอมพิวเตอร์"}

print(student)
# Out:
# {'name': 'สมชาย', 'age': 20, 'grade': 'A', 'major': 'วิทยาการคอมพิวเตอร์'}

# %% [markdown]
# ## ข้อ 2: เพิ่ม แก้ไข และลบข้อมูลใน Dictionary
#
# ให้ใช้ dictionary จากข้อ 1 แล้วทำดังนี้:
# - เพิ่มคีย์ใหม่ "city" ที่มีค่า "กรุงเทพ"
# - เปลี่ยนอายุเป็น 21
# - ลบคีย์ "major" ออก
#
# จากนั้นให้พิมพ์ dictionary ทั้งหมด

# %%
# เขียนคำตอบของคุณที่นี่
student = {"name":"สมชาย", "age":20, "grade":"A", "major":"วิทยาการคอมพิวเตอร์"}

student ["city"] = "กรุงเทพ"
student ["age"] = 18

del student["major"]

print(student)
# Out:
# {'name': 'สมชาย', 'age': 18, 'grade': 'A', 'city': 'กรุงเทพ'}

# %% [markdown]
# ## ข้อ 3: การวนลูปผ่าน Dictionary
#
# สร้าง dictionary ชื่อ `prices` ที่เก็บราคาสินค้า:
# ```python
# prices = {
#     "apple": 25,
#     "banana": 15,
#     "orange": 30,
#     "mango": 50
# }
# ```
#
# ให้พิมพ์ชื่อสินค้าและราคาในรูปแบบ "แอปเปิล: 25 บาท"

# %%
# เขียนคำตอบของคุณที่นี่
prices = {
    "apple": 25,
    "banana": 15,
    "orange": 30,
    "mango": 50
}
names_th = {
    "apple": "แอปเปิล",
    "banana": "กล้วย",
    "orange": "ส้ม",
    "mango": "มะม่วง"
}

for key, price in prices.items():
    print(f"{names_th[key]}: {price} บาท")
# Out:
# แอปเปิล: 25 บาท
# กล้วย: 15 บาท
# ส้ม: 30 บาท
# มะม่วง: 50 บาท

# %% [markdown]
# ## ข้อ 4: Tuple - สร้างและเข้าถึงค่า
#
# สร้าง tuple ชื่อ `coordinates` ที่มีค่า (10, 20, 30)
#
# จากนั้นให้พิมพ์:
# - ค่าตัวแรก
# - ค่าตัวสุดท้าย
# - ค่าสามค่า (ใช้ slicing)
# - จำนวนสมาชิกทั้งหมด

# %%
# เขียนคำตอบของคุณที่นี่
coordinates = (10, 20, 30)

print(coordinates[0])
print(coordinates[-1])
print(coordinates[:])
print(len(coordinates))
# Out:
# 10
# 30
# (10, 20, 30)
# 3

# %% [markdown]
# ## ข้อ 5: Tuple ไม่สามารถเปลี่ยนแปลง (Immutable)
#
# สร้าง tuple ชื่อ `colors` ที่มีค่า ("red", "green", "blue")
#
# พยายามเปลี่ยนค่าตัวแรกเป็น "yellow" และบันทึกข้อความ error ที่ได้รับ
#
# จากนั้นให้อธิบายว่าทำไม tuple ถึงไม่สามารถเปลี่ยนแปลงได้

# %%
# เขียนคำตอบของคุณที่นี่
colors = ("red", "green", "blue")

colors ["red"] = "yellow"
---------------------------------------------------------------------------
TypeError                                 Traceback (most recent call last)
Cell In[23], line 4
      1 # เขียนคำตอบของคุณที่นี่
      2 colors = ("red", "green", "blue")
----> 4 colors ["red"] = "yellow"

TypeError: 'tuple' object does not support item assignment

# คำอธิบาย
# Tuple นั้นจะมีลักษณะคงที่ไม่สามารถทำการเปลี่ยนแปลงค่าของสมาชิกหลังจากถูกสร้างขึ้น ซึ่งหมายความว่าข้อมูลสมาชิกของ Tuple ไม่สามารถเปลี่ยนแปลงได้เมื่อมีการกำหนดค่าแล้ว
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 4
#       1 # เขียนคำตอบของคุณที่นี่
#       2 colors = ("red", "green", "blue")
# ----> 4 colors ["red"] = "yellow"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## ข้อ 6: Dictionary ที่มีค่าเป็น Tuple
#
# สร้าง dictionary ชื่อ `students_scores` ที่เก็บข้อมูลนักเรียน:
# ```python
# students_scores = {
#     "นักเรียน1": (85, 90, 88),
#     "นักเรียน2": (75, 80, 78),
#     "นักเรียน3": (95, 92, 94)
# }
# ```
#
# ให้คำนวณค่าเฉลี่ยคะแนนของนักเรียนแต่ละคน และพิมพ์ผลลัพธ์

# %%
# เขียนคำตอบของคุณที่นี่
students_scores = {
    "นักเรียน1": (85, 90, 88),
    "นักเรียน2": (75, 80, 78),
    "นักเรียน3": (95, 92, 94)
}
for name, scores in students_scores.items():
    average = sum(scores) / len(scores)
    print(f"{name} ค่าเฉลี่ย = {average:.2f}")
# Out:
# นักเรียน1 ค่าเฉลี่ย = 87.67
# นักเรียน2 ค่าเฉลี่ย = 77.67
# นักเรียน3 ค่าเฉลี่ย = 93.67

# %% [markdown]
# ## ข้อ 7: ค้นหาข้อมูลใน Dictionary
#
# สร้าง dictionary ชื่อ `phone_book` ที่เก็บหมายเลขโทรศัพท์:
# ```python
# phone_book = {
#     "สมชาย": "081-234-5678",
#     "สมหญิง": "089-876-5432",
#     "สมศรี": "085-111-2222"
# }
# ```
#
# ให้สร้างฟังก์ชันที่ค้นหาหมายเลขโทรศัพท์ตามชื่อ และถ้าไม่พบให้แสดงข้อความ "ไม่พบข้อมูล"

# %%
# เขียนคำตอบของคุณที่นี่
phone_book = {
    "สมชาย": "081-234-5678",
    "สมหญิง": "089-876-5432",
    "สมศรี": "085-111-2222"
}

def search_phone(name):
    if name in phone_book:
        return phone_book[name]
    else:
        return "ไม่พบข้อมูล"
        
print(search_phone("สมชาย"))
print(search_phone("สมปอง"))
# Out:
# 081-234-5678
# ไม่พบข้อมูล

# %% [markdown]
# ## ข้อ 8: Tuple Unpacking
#
# สร้าง tuple ชื่อ `person_info` ที่มีค่า ("วิชา", 22, "engineer")
#
# ให้ใช้ tuple unpacking เพื่อกำหนดค่าให้กับตัวแปร name, age, และ job
#
# จากนั้นพิมพ์ข้อมูลทั้งหมดในรูปแบบ "วิชา อายุ 22 ปี ประกอบอาชีพ engineer"

# %%
# เขียนคำตอบของคุณที่นี่
person_info = ("วิชา", 22, "engineer")

name, age, job = person_info

print(f"{name} อายุ {age} ปี ประกอบอาชีพ {job}")
# Out:
# วิชา อายุ 22 ปี ประกอบอาชีพ engineer

# %% [markdown]
# ## ข้อ 9: การรวม Dictionary
#
# สร้าง dictionary 2 อัน:
# - `person1 = {"name": "สมชาย", "age": 25}`
# - `person2 = {"name": "สมหญิง", "age": 24}`
#
# ให้รวม dictionary ทั้งสองเป็น dictionary เดียวชื่อ `all_people` และพิมพ์ผลลัพธ์
#
# หมายเหตุ: ลองใช้วิธีต่างๆ เช่น update(), {**dict1, **dict2} เป็นต้น

# %%
# เขียนคำตอบของคุณที่นี่
person1 = {"name": "สมชาย", "age": 25}
person2 = {"name": "สมหญิง", "age": 24}

# --- วิธีที่ 1 ใช้ update() ---
all_people1 = person1.copy()
all_people1.update(person2)

print("วิธีที่ 1 (update):", all_people1)

# --- วิธีที่ 2 ใช้ {**dict1, **dict2} ---
all_people2 = {**person1, **person2}

print("วิธีที่ 2 ({**dict1, **dict2}):", all_people2)

# --- วิธีที่ 3 ใช้ union operator (Python 3.9+) ---
all_people3 = person1 | person2

print("วิธีที่ 3 (| operator):", all_people3)
# Out:
# วิธีที่ 1 (update): {'name': 'สมหญิง', 'age': 24}
# วิธีที่ 2 ({**dict1, **dict2}): {'name': 'สมหญิง', 'age': 24}
# วิธีที่ 3 (| operator): {'name': 'สมหญิง', 'age': 24}

# %% [markdown]
# ## ข้อ 10: โปรแกรมจัดการสินค้า (Challenge)
#
# สร้างโปรแกรมจัดการสินค้าที่มีความสามารถดังนี้:
#
# 1. มี dictionary ชื่อ `inventory` ที่เก็บข้อมูลสินค้า: ชื่อสินค้า, จำนวน, และราคา (เก็บในรูป tuple)
# 2. สร้างฟังก์ชน `add_product()` เพื่อเพิ่มสินค้าใหม่
# 3. สร้างฟังก์ชั่น `update_quantity()` เพื่ออัปเดตจำนวนสินค้า
# 4. สร้างฟังก์ชั่น `get_total_value()` เพื่อคำนวณมูลค่ารวมของสินค้า
# 5. สร้างฟังก์ชั่น `show_inventory()` เพื่อแสดงรายการสินค้าทั้งหมด
#
# ตัวอย่างการใช้งาน:
# ```
# Inventory: {'น้ำตาล': (10, 50), 'แป้งมัน': (5, 100)}
# Total value: 1000 บาท
# ```

# %%
# เขียนคำตอบของคุณที่นี่
# เก็บข้อมูลสินค้าในรูปแบบ: "ชื่อสินค้า": (จำนวน, ราคา)
inventory = {
    "น้ำตาล": (10, 50),
    "แป้งมัน": (5, 100)
}

# เพิ่มสินค้าใหม่
def add_product(name, quantity, price):
    if name in inventory:
        print("สินค้านี้มีอยู่แล้วในระบบ!")
    else:
        inventory[name] = (quantity, price)
        print(f"เพิ่มสินค้า {name} เรียบร้อย")

# อัปเดตจำนวนสินค้า
def update_quantity(name, new_quantity):
    if name in inventory:
        price = inventory[name][1]
        inventory[name] = (new_quantity, price)
        print(f"อัปเดตจำนวนสินค้า {name} เป็น {new_quantity}")
    else:
        print("ไม่พบสินค้าในระบบ")

# คำนวณมูลค่ารวมของสินค้า
def get_total_value():
    total = 0
    for qty, price in inventory.values():
        total += qty * price
    return total

# แสดงรายการสินค้า
def show_inventory():
    print("=== รายการสินค้า ===")
    for name, (qty, price) in inventory.items():
        print(f"{name}: จำนวน {qty}, ราคา {price} บาท/หน่วย")
    print("=====================")

# %%
# -----------------------------
# ตัวอย่างการใช้งาน
# -----------------------------

show_inventory()

print("Total value:", get_total_value(), "บาท")

add_product("น้ำปลา", 20, 30)
update_quantity("น้ำตาล", 15)

show_inventory()
print("Total value:", get_total_value(), "บาท")
# Out:
# === รายการสินค้า ===
# น้ำตาล: จำนวน 10, ราคา 50 บาท/หน่วย
# แป้งมัน: จำนวน 5, ราคา 100 บาท/หน่วย
# =====================
# Total value: 1000 บาท
# เพิ่มสินค้า น้ำปลา เรียบร้อย
# อัปเดตจำนวนสินค้า น้ำตาล เป็น 15
# === รายการสินค้า ===
# น้ำตาล: จำนวน 15, ราคา 50 บาท/หน่วย
# แป้งมัน: จำนวน 5, ราคา 100 บาท/หน่วย
# น้ำปลา: จำนวน 20, ราคา 30 บาท/หน่วย
# =====================
# Total value: 1850 บาท
